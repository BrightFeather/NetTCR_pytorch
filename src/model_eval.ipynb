# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
sys.path.append("/Users/chenweijia/Documents/code/nettcr_pytorch/src")

# %%
import onnxruntime as ort

import onnx
import torch

import numpy as np
import pandas as pd 
import random
import time

from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score

# import dataset
# import constants
from dataset import CustomDataset
from constants import blosum50_20aa

# %%
def print_model_info(model_path):
    # Load the ONNX model
    model = onnx.load(model_path)

    # Print the model's input information
    print("Model Inputs:")
    for input_tensor in model.graph.input:
        print(f"Name: {input_tensor.name}")
        # Tensor shape may be None or empty in some ONNX models if not explicitly set
        shape = [dim.dim_value for dim in input_tensor.type.tensor_type.shape.dim]
        print(f"Shape: {shape}")
        print(f"Type: {input_tensor.type.tensor_type.elem_type}")  # This is an integer representing a data type

    # Print the model architecture by iterating over all nodes in the graph
    print("\nModel Architecture:")
    for node in model.graph.node:
        print(f"Node name: {node.name}")
        print(f"Node type: {node.op_type}")
        print(f"Inputs: {node.input}")
        print(f"Outputs: {node.output}")
        print("---")

# Example usage
model_path = 'models/onnx/t.0.v.1.onnx'
print_model_info(model_path)
# Out:
# Model Inputs:
# Name: serving_default_a2:0
# Shape: [0, 8, 20]
# Type: 1
# Name: serving_default_a1:0
# Shape: [0, 7, 20]
# Type: 1
# Name: serving_default_b2:0
# Shape: [0, 7, 20]
# Type: 1
# Name: serving_default_b1:0
# Shape: [0, 6, 20]
# Type: 1
# Name: serving_default_a3:0
# Shape: [0, 22, 20]
# Type: 1
# Name: serving_default_b3:0
# Shape: [0, 23, 20]
# Type: 1
# Name: serving_default_pep:0
# Shape: [0, 12, 20]
# Type: 1
#
# Model Architecture:
# Node name: model/conv1d_5/Conv1D/ExpandDims
# Node type: Unsqueeze
# Inputs: ['serving_default_a1:0', 'const_fold_opt__428']
# Outputs: ['model/conv1d_5/Conv1D/ExpandDims']
# ---
# Node name: model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D__119
# Node type: Transpose
# Inputs: ['model/conv1d_5/Conv1D/ExpandDims']
# Outputs: ['model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D__119:0']
# ---
# Node name: model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D__119:0', 'const_fold_opt__446', 'model/conv1d_9/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D']
# ---
# Node name: model/conv1d_8/Relu;model/conv1d_8/BiasAdd;model/conv1d_8/Conv1D/Squeeze;model/conv1d_8/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_8/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D__119:0', 'const_fold_opt__449', 'model/conv1d_8/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_8/Relu;model/conv1d_8/BiasAdd;model/conv1d_8/Conv1D/Squeeze;model/conv1d_8/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_8/Conv1D']
# ---
# Node name: model/conv1d_6/Relu;model/conv1d_6/BiasAdd;model/conv1d_6/Conv1D/Squeeze;model/conv1d_6/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_6/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D__119:0', 'const_fold_opt__456', 'model/conv1d_6/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_6/Relu;model/conv1d_6/BiasAdd;model/conv1d_6/Conv1D/Squeeze;model/conv1d_6/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_6/Conv1D']
# ---
# Node name: model/conv1d_30/Conv1D/ExpandDims
# Node type: Unsqueeze
# Inputs: ['serving_default_b3:0', 'const_fold_opt__428']
# Outputs: ['model/conv1d_30/Conv1D/ExpandDims']
# ---
# Node name: model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D__147
# Node type: Transpose
# Inputs: ['model/conv1d_30/Conv1D/ExpandDims']
# Outputs: ['model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D__147:0']
# ---
# Node name: model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D__147:0', 'const_fold_opt__440', 'model/conv1d_34/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D']
# ---
# Node name: model/conv1d_31/Relu;model/conv1d_31/BiasAdd;model/conv1d_31/Conv1D/Squeeze;model/conv1d_31/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_31/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D__147:0', 'const_fold_opt__458', 'model/conv1d_31/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_31/Relu;model/conv1d_31/BiasAdd;model/conv1d_31/Conv1D/Squeeze;model/conv1d_31/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_31/Conv1D']
# ---
# Node name: model/conv1d_30/Relu;model/conv1d_30/BiasAdd;model/conv1d_30/Conv1D/Squeeze;model/conv1d_30/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_30/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D__147:0', 'const_fold_opt__461', 'model/conv1d_30/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_30/Relu;model/conv1d_30/BiasAdd;model/conv1d_30/Conv1D/Squeeze;model/conv1d_30/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_30/Conv1D']
# ---
# Node name: model/conv1d_25/Conv1D/ExpandDims
# Node type: Unsqueeze
# Inputs: ['serving_default_b2:0', 'const_fold_opt__428']
# Outputs: ['model/conv1d_25/Conv1D/ExpandDims']
# ---
# Node name: model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D__175
# Node type: Transpose
# Inputs: ['model/conv1d_25/Conv1D/ExpandDims']
# Outputs: ['model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D__175:0']
# ---
# Node name: model/conv1d_20/Conv1D/ExpandDims
# Node type: Unsqueeze
# Inputs: ['serving_default_b1:0', 'const_fold_opt__428']
# Outputs: ['model/conv1d_20/Conv1D/ExpandDims']
# ---
# Node name: model/conv1d_24/Relu;model/conv1d_24/BiasAdd;model/conv1d_24/Conv1D/Squeeze;model/conv1d_24/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_24/Conv1D__203
# Node type: Transpose
# Inputs: ['model/conv1d_20/Conv1D/ExpandDims']
# Outputs: ['model/conv1d_24/Relu;model/conv1d_24/BiasAdd;model/conv1d_24/Conv1D/Squeeze;model/conv1d_24/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_24/Conv1D__203:0']
# ---
# Node name: model/conv1d_24/Relu;model/conv1d_24/BiasAdd;model/conv1d_24/Conv1D/Squeeze;model/conv1d_24/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_24/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_24/Relu;model/conv1d_24/BiasAdd;model/conv1d_24/Conv1D/Squeeze;model/conv1d_24/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_24/Conv1D__203:0', 'const_fold_opt__444', 'model/conv1d_24/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_24/Relu;model/conv1d_24/BiasAdd;model/conv1d_24/Conv1D/Squeeze;model/conv1d_24/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_24/Conv1D']
# ---
# Node name: model/conv1d_15/Conv1D/ExpandDims
# Node type: Unsqueeze
# Inputs: ['serving_default_a3:0', 'const_fold_opt__428']
# Outputs: ['model/conv1d_15/Conv1D/ExpandDims']
# ---
# Node name: model/conv1d_19/Relu;model/conv1d_19/BiasAdd;model/conv1d_19/Conv1D/Squeeze;model/conv1d_19/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_19/Conv1D__231
# Node type: Transpose
# Inputs: ['model/conv1d_15/Conv1D/ExpandDims']
# Outputs: ['model/conv1d_19/Relu;model/conv1d_19/BiasAdd;model/conv1d_19/Conv1D/Squeeze;model/conv1d_19/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_19/Conv1D__231:0']
# ---
# Node name: model/conv1d_17/Relu;model/conv1d_17/BiasAdd;model/conv1d_17/Conv1D/Squeeze;model/conv1d_17/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_17/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_19/Relu;model/conv1d_19/BiasAdd;model/conv1d_19/Conv1D/Squeeze;model/conv1d_19/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_19/Conv1D__231:0', 'const_fold_opt__432', 'model/conv1d_17/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_17/Relu;model/conv1d_17/BiasAdd;model/conv1d_17/Conv1D/Squeeze;model/conv1d_17/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_17/Conv1D']
# ---
# Node name: model/conv1d_16/Relu;model/conv1d_16/BiasAdd;model/conv1d_16/Conv1D/Squeeze;model/conv1d_16/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_16/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_19/Relu;model/conv1d_19/BiasAdd;model/conv1d_19/Conv1D/Squeeze;model/conv1d_19/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_19/Conv1D__231:0', 'const_fold_opt__463', 'model/conv1d_16/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_16/Relu;model/conv1d_16/BiasAdd;model/conv1d_16/Conv1D/Squeeze;model/conv1d_16/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_16/Conv1D']
# ---
# Node name: model/conv1d_15/Relu;model/conv1d_15/BiasAdd;model/conv1d_15/Conv1D/Squeeze;model/conv1d_15/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_15/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_19/Relu;model/conv1d_19/BiasAdd;model/conv1d_19/Conv1D/Squeeze;model/conv1d_19/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_19/Conv1D__231:0', 'const_fold_opt__438', 'model/conv1d_15/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_15/Relu;model/conv1d_15/BiasAdd;model/conv1d_15/Conv1D/Squeeze;model/conv1d_15/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_15/Conv1D']
# ---
# Node name: model/conv1d_10/Conv1D/ExpandDims
# Node type: Unsqueeze
# Inputs: ['serving_default_a2:0', 'const_fold_opt__428']
# Outputs: ['model/conv1d_10/Conv1D/ExpandDims']
# ---
# Node name: model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D__259
# Node type: Transpose
# Inputs: ['model/conv1d_10/Conv1D/ExpandDims']
# Outputs: ['model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D__259:0']
# ---
# Node name: model/conv1d/Conv1D/ExpandDims
# Node type: Unsqueeze
# Inputs: ['serving_default_pep:0', 'const_fold_opt__428']
# Outputs: ['model/conv1d/Conv1D/ExpandDims']
# ---
# Node name: model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D__287
# Node type: Transpose
# Inputs: ['model/conv1d/Conv1D/ExpandDims']
# Outputs: ['model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D__287:0']
# ---
# Node name: model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D__287:0', 'const_fold_opt__433', 'model/conv1d_4/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D']
# ---
# Node name: model/conv1d_3/Relu;model/conv1d_3/BiasAdd;model/conv1d_3/Conv1D/Squeeze;model/conv1d_3/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_3/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D__287:0', 'const_fold_opt__437', 'model/conv1d_3/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_3/Relu;model/conv1d_3/BiasAdd;model/conv1d_3/Conv1D/Squeeze;model/conv1d_3/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_3/Conv1D']
# ---
# Node name: model/conv1d/Relu;model/conv1d/BiasAdd;model/conv1d/Conv1D/Squeeze;model/conv1d/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D__287:0', 'const_fold_opt__455', 'model/conv1d/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d/Relu;model/conv1d/BiasAdd;model/conv1d/Conv1D/Squeeze;model/conv1d/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d/Conv1D']
# ---
# Node name: model/conv1d_18/Relu;model/conv1d_18/BiasAdd;model/conv1d_18/Conv1D/Squeeze;model/conv1d_18/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_18/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_19/Relu;model/conv1d_19/BiasAdd;model/conv1d_19/Conv1D/Squeeze;model/conv1d_19/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_19/Conv1D__231:0', 'const_fold_opt__426', 'model/conv1d_18/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_18/Relu;model/conv1d_18/BiasAdd;model/conv1d_18/Conv1D/Squeeze;model/conv1d_18/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_18/Conv1D']
# ---
# Node name: model/conv1d_5/Relu;model/conv1d_5/BiasAdd;model/conv1d_5/Conv1D/Squeeze;model/conv1d_5/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_5/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D__119:0', 'const_fold_opt__423', 'model/conv1d_5/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_5/Relu;model/conv1d_5/BiasAdd;model/conv1d_5/Conv1D/Squeeze;model/conv1d_5/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_5/Conv1D']
# ---
# Node name: model/conv1d_19/Relu;model/conv1d_19/BiasAdd;model/conv1d_19/Conv1D/Squeeze;model/conv1d_19/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_19/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_19/Relu;model/conv1d_19/BiasAdd;model/conv1d_19/Conv1D/Squeeze;model/conv1d_19/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_19/Conv1D__231:0', 'const_fold_opt__420', 'model/conv1d_19/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_19/Relu;model/conv1d_19/BiasAdd;model/conv1d_19/Conv1D/Squeeze;model/conv1d_19/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_19/Conv1D']
# ---
# Node name: model/conv1d_32/Relu;model/conv1d_32/BiasAdd;model/conv1d_32/Conv1D/Squeeze;model/conv1d_32/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_32/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D__147:0', 'const_fold_opt__415', 'model/conv1d_32/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_32/Relu;model/conv1d_32/BiasAdd;model/conv1d_32/Conv1D/Squeeze;model/conv1d_32/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_32/Conv1D']
# ---
# Node name: model/conv1d_2/Relu;model/conv1d_2/BiasAdd;model/conv1d_2/Conv1D/Squeeze;model/conv1d_2/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_2/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D__287:0', 'const_fold_opt__412', 'model/conv1d_2/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_2/Relu;model/conv1d_2/BiasAdd;model/conv1d_2/Conv1D/Squeeze;model/conv1d_2/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_2/Conv1D']
# ---
# Node name: model/conv1d_33/Relu;model/conv1d_33/BiasAdd;model/conv1d_33/Conv1D/Squeeze;model/conv1d_33/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_33/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D__147:0', 'const_fold_opt__406', 'model/conv1d_33/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_33/Relu;model/conv1d_33/BiasAdd;model/conv1d_33/Conv1D/Squeeze;model/conv1d_33/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_33/Conv1D']
# ---
# Node name: model/conv1d_20/Relu;model/conv1d_20/BiasAdd;model/conv1d_20/Conv1D/Squeeze;model/conv1d_20/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_20/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_24/Relu;model/conv1d_24/BiasAdd;model/conv1d_24/Conv1D/Squeeze;model/conv1d_24/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_24/Conv1D__203:0', 'const_fold_opt__405', 'model/conv1d_20/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_20/Relu;model/conv1d_20/BiasAdd;model/conv1d_20/Conv1D/Squeeze;model/conv1d_20/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_20/Conv1D']
# ---
# Node name: model/conv1d_7/Relu;model/conv1d_7/BiasAdd;model/conv1d_7/Conv1D/Squeeze;model/conv1d_7/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_7/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D__119:0', 'const_fold_opt__402', 'model/conv1d_7/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_7/Relu;model/conv1d_7/BiasAdd;model/conv1d_7/Conv1D/Squeeze;model/conv1d_7/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_7/Conv1D']
# ---
# Node name: model/conv1d_21/Relu;model/conv1d_21/BiasAdd;model/conv1d_21/Conv1D/Squeeze;model/conv1d_21/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_21/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_24/Relu;model/conv1d_24/BiasAdd;model/conv1d_24/Conv1D/Squeeze;model/conv1d_24/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_24/Conv1D__203:0', 'const_fold_opt__396', 'model/conv1d_21/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_21/Relu;model/conv1d_21/BiasAdd;model/conv1d_21/Conv1D/Squeeze;model/conv1d_21/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_21/Conv1D']
# ---
# Node name: model/conv1d_22/Relu;model/conv1d_22/BiasAdd;model/conv1d_22/Conv1D/Squeeze;model/conv1d_22/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_22/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_24/Relu;model/conv1d_24/BiasAdd;model/conv1d_24/Conv1D/Squeeze;model/conv1d_24/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_24/Conv1D__203:0', 'const_fold_opt__392', 'model/conv1d_22/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_22/Relu;model/conv1d_22/BiasAdd;model/conv1d_22/Conv1D/Squeeze;model/conv1d_22/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_22/Conv1D']
# ---
# Node name: model/conv1d_23/Relu;model/conv1d_23/BiasAdd;model/conv1d_23/Conv1D/Squeeze;model/conv1d_23/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_23/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_24/Relu;model/conv1d_24/BiasAdd;model/conv1d_24/Conv1D/Squeeze;model/conv1d_24/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_24/Conv1D__203:0', 'const_fold_opt__388', 'model/conv1d_23/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_23/Relu;model/conv1d_23/BiasAdd;model/conv1d_23/Conv1D/Squeeze;model/conv1d_23/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_23/Conv1D']
# ---
# Node name: model/conv1d_1/Relu;model/conv1d_1/BiasAdd;model/conv1d_1/Conv1D/Squeeze;model/conv1d_1/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_1/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D__287:0', 'const_fold_opt__385', 'model/conv1d_1/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_1/Relu;model/conv1d_1/BiasAdd;model/conv1d_1/Conv1D/Squeeze;model/conv1d_1/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_1/Conv1D']
# ---
# Node name: model/conv1d_10/Relu;model/conv1d_10/BiasAdd;model/conv1d_10/Conv1D/Squeeze;model/conv1d_10/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_10/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D__259:0', 'const_fold_opt__379', 'model/conv1d_10/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_10/Relu;model/conv1d_10/BiasAdd;model/conv1d_10/Conv1D/Squeeze;model/conv1d_10/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_10/Conv1D']
# ---
# Node name: model/conv1d_25/Relu;model/conv1d_25/BiasAdd;model/conv1d_25/Conv1D/Squeeze;model/conv1d_25/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_25/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D__175:0', 'const_fold_opt__377', 'model/conv1d_25/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_25/Relu;model/conv1d_25/BiasAdd;model/conv1d_25/Conv1D/Squeeze;model/conv1d_25/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_25/Conv1D']
# ---
# Node name: model/conv1d_26/Relu;model/conv1d_26/BiasAdd;model/conv1d_26/Conv1D/Squeeze;model/conv1d_26/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_26/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D__175:0', 'const_fold_opt__373', 'model/conv1d_26/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_26/Relu;model/conv1d_26/BiasAdd;model/conv1d_26/Conv1D/Squeeze;model/conv1d_26/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_26/Conv1D']
# ---
# Node name: model/conv1d_11/Relu;model/conv1d_11/BiasAdd;model/conv1d_11/Conv1D/Squeeze;model/conv1d_11/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_11/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D__259:0', 'const_fold_opt__372', 'model/conv1d_11/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_11/Relu;model/conv1d_11/BiasAdd;model/conv1d_11/Conv1D/Squeeze;model/conv1d_11/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_11/Conv1D']
# ---
# Node name: model/conv1d_27/Relu;model/conv1d_27/BiasAdd;model/conv1d_27/Conv1D/Squeeze;model/conv1d_27/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_27/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D__175:0', 'const_fold_opt__367', 'model/conv1d_27/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_27/Relu;model/conv1d_27/BiasAdd;model/conv1d_27/Conv1D/Squeeze;model/conv1d_27/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_27/Conv1D']
# ---
# Node name: model/conv1d_12/Relu;model/conv1d_12/BiasAdd;model/conv1d_12/Conv1D/Squeeze;model/conv1d_12/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_12/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D__259:0', 'const_fold_opt__365', 'model/conv1d_12/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_12/Relu;model/conv1d_12/BiasAdd;model/conv1d_12/Conv1D/Squeeze;model/conv1d_12/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_12/Conv1D']
# ---
# Node name: model/conv1d_13/Relu;model/conv1d_13/BiasAdd;model/conv1d_13/Conv1D/Squeeze;model/conv1d_13/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_13/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D__259:0', 'const_fold_opt__361', 'model/conv1d_13/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_13/Relu;model/conv1d_13/BiasAdd;model/conv1d_13/Conv1D/Squeeze;model/conv1d_13/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_13/Conv1D']
# ---
# Node name: model/conv1d_28/Relu;model/conv1d_28/BiasAdd;model/conv1d_28/Conv1D/Squeeze;model/conv1d_28/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_28/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D__175:0', 'const_fold_opt__360', 'model/conv1d_28/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_28/Relu;model/conv1d_28/BiasAdd;model/conv1d_28/Conv1D/Squeeze;model/conv1d_28/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_28/Conv1D']
# ---
# Node name: model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D__259:0', 'const_fold_opt__355', 'model/conv1d_14/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D']
# ---
# Node name: model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D
# Node type: Conv
# Inputs: ['model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D__175:0', 'const_fold_opt__353', 'model/conv1d_29/BiasAdd/ReadVariableOp']
# Outputs: ['model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D']
# ---
# Node name: Relu__98
# Node type: Relu
# Inputs: ['model/conv1d_1/Relu;model/conv1d_1/BiasAdd;model/conv1d_1/Conv1D/Squeeze;model/conv1d_1/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_1/Conv1D']
# Outputs: ['Relu__98:0']
# ---
# Node name: model/conv1d_1/Relu;model/conv1d_1/BiasAdd;model/conv1d_1/Conv1D/Squeeze;model/conv1d_1/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_1/Conv1D__305
# Node type: Transpose
# Inputs: ['Relu__98:0']
# Outputs: ['model/conv1d_1/Relu;model/conv1d_1/BiasAdd;model/conv1d_1/Conv1D/Squeeze;model/conv1d_1/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_1/Conv1D__305:0']
# ---
# Node name: model/conv1d_1/Relu;model/conv1d_1/BiasAdd;model/conv1d_1/Conv1D/Squeeze;model/conv1d_1/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_1/Relu;model/conv1d_1/BiasAdd;model/conv1d_1/Conv1D/Squeeze;model/conv1d_1/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_1/Conv1D__305:0', 'const_fold_opt__435']
# Outputs: ['model/conv1d_1/Relu;model/conv1d_1/BiasAdd;model/conv1d_1/Conv1D/Squeeze;model/conv1d_1/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_1/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_1/Relu;model/conv1d_1/BiasAdd;model/conv1d_1/Conv1D/Squeeze;model/conv1d_1/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_1/Max']
# ---
# Node name: Relu__95
# Node type: Relu
# Inputs: ['model/conv1d/Relu;model/conv1d/BiasAdd;model/conv1d/Conv1D/Squeeze;model/conv1d/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d/Conv1D']
# Outputs: ['Relu__95:0']
# ---
# Node name: model/conv1d/Relu;model/conv1d/BiasAdd;model/conv1d/Conv1D/Squeeze;model/conv1d/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d/Conv1D__310
# Node type: Transpose
# Inputs: ['Relu__95:0']
# Outputs: ['model/conv1d/Relu;model/conv1d/BiasAdd;model/conv1d/Conv1D/Squeeze;model/conv1d/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d/Conv1D__310:0']
# ---
# Node name: model/conv1d/Relu;model/conv1d/BiasAdd;model/conv1d/Conv1D/Squeeze;model/conv1d/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d/Relu;model/conv1d/BiasAdd;model/conv1d/Conv1D/Squeeze;model/conv1d/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d/Conv1D__310:0', 'const_fold_opt__435']
# Outputs: ['model/conv1d/Relu;model/conv1d/BiasAdd;model/conv1d/Conv1D/Squeeze;model/conv1d/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d/Relu;model/conv1d/BiasAdd;model/conv1d/Conv1D/Squeeze;model/conv1d/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d/Max']
# ---
# Node name: Relu__92
# Node type: Relu
# Inputs: ['model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D']
# Outputs: ['Relu__92:0']
# ---
# Node name: model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D__122
# Node type: Transpose
# Inputs: ['Relu__92:0']
# Outputs: ['model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D__122:0']
# ---
# Node name: model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_9/Conv1D__122:0', 'const_fold_opt__439']
# Outputs: ['model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_9/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_9/Relu;model/conv1d_9/BiasAdd;model/conv1d_9/Conv1D/Squeeze;model/conv1d_9/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_9/Max']
# ---
# Node name: Relu__89
# Node type: Relu
# Inputs: ['model/conv1d_8/Relu;model/conv1d_8/BiasAdd;model/conv1d_8/Conv1D/Squeeze;model/conv1d_8/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_8/Conv1D']
# Outputs: ['Relu__89:0']
# ---
# Node name: model/conv1d_8/Relu;model/conv1d_8/BiasAdd;model/conv1d_8/Conv1D/Squeeze;model/conv1d_8/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_8/Conv1D__127
# Node type: Transpose
# Inputs: ['Relu__89:0']
# Outputs: ['model/conv1d_8/Relu;model/conv1d_8/BiasAdd;model/conv1d_8/Conv1D/Squeeze;model/conv1d_8/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_8/Conv1D__127:0']
# ---
# Node name: model/conv1d_8/Relu;model/conv1d_8/BiasAdd;model/conv1d_8/Conv1D/Squeeze;model/conv1d_8/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_8/Relu;model/conv1d_8/BiasAdd;model/conv1d_8/Conv1D/Squeeze;model/conv1d_8/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_8/Conv1D__127:0', 'const_fold_opt__439']
# Outputs: ['model/conv1d_8/Relu;model/conv1d_8/BiasAdd;model/conv1d_8/Conv1D/Squeeze;model/conv1d_8/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_8/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_8/Relu;model/conv1d_8/BiasAdd;model/conv1d_8/Conv1D/Squeeze;model/conv1d_8/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_8/Max']
# ---
# Node name: Relu__86
# Node type: Relu
# Inputs: ['model/conv1d_7/Relu;model/conv1d_7/BiasAdd;model/conv1d_7/Conv1D/Squeeze;model/conv1d_7/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_7/Conv1D']
# Outputs: ['Relu__86:0']
# ---
# Node name: model/conv1d_7/Relu;model/conv1d_7/BiasAdd;model/conv1d_7/Conv1D/Squeeze;model/conv1d_7/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_7/Conv1D__132
# Node type: Transpose
# Inputs: ['Relu__86:0']
# Outputs: ['model/conv1d_7/Relu;model/conv1d_7/BiasAdd;model/conv1d_7/Conv1D/Squeeze;model/conv1d_7/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_7/Conv1D__132:0']
# ---
# Node name: model/conv1d_7/Relu;model/conv1d_7/BiasAdd;model/conv1d_7/Conv1D/Squeeze;model/conv1d_7/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_7/Relu;model/conv1d_7/BiasAdd;model/conv1d_7/Conv1D/Squeeze;model/conv1d_7/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_7/Conv1D__132:0', 'const_fold_opt__439']
# Outputs: ['model/conv1d_7/Relu;model/conv1d_7/BiasAdd;model/conv1d_7/Conv1D/Squeeze;model/conv1d_7/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_7/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_7/Relu;model/conv1d_7/BiasAdd;model/conv1d_7/Conv1D/Squeeze;model/conv1d_7/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_7/Max']
# ---
# Node name: Relu__83
# Node type: Relu
# Inputs: ['model/conv1d_6/Relu;model/conv1d_6/BiasAdd;model/conv1d_6/Conv1D/Squeeze;model/conv1d_6/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_6/Conv1D']
# Outputs: ['Relu__83:0']
# ---
# Node name: model/conv1d_6/Relu;model/conv1d_6/BiasAdd;model/conv1d_6/Conv1D/Squeeze;model/conv1d_6/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_6/Conv1D__137
# Node type: Transpose
# Inputs: ['Relu__83:0']
# Outputs: ['model/conv1d_6/Relu;model/conv1d_6/BiasAdd;model/conv1d_6/Conv1D/Squeeze;model/conv1d_6/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_6/Conv1D__137:0']
# ---
# Node name: model/conv1d_6/Relu;model/conv1d_6/BiasAdd;model/conv1d_6/Conv1D/Squeeze;model/conv1d_6/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_6/Relu;model/conv1d_6/BiasAdd;model/conv1d_6/Conv1D/Squeeze;model/conv1d_6/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_6/Conv1D__137:0', 'const_fold_opt__439']
# Outputs: ['model/conv1d_6/Relu;model/conv1d_6/BiasAdd;model/conv1d_6/Conv1D/Squeeze;model/conv1d_6/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_6/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_6/Relu;model/conv1d_6/BiasAdd;model/conv1d_6/Conv1D/Squeeze;model/conv1d_6/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_6/Max']
# ---
# Node name: Relu__80
# Node type: Relu
# Inputs: ['model/conv1d_5/Relu;model/conv1d_5/BiasAdd;model/conv1d_5/Conv1D/Squeeze;model/conv1d_5/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_5/Conv1D']
# Outputs: ['Relu__80:0']
# ---
# Node name: model/conv1d_5/Relu;model/conv1d_5/BiasAdd;model/conv1d_5/Conv1D/Squeeze;model/conv1d_5/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_5/Conv1D__142
# Node type: Transpose
# Inputs: ['Relu__80:0']
# Outputs: ['model/conv1d_5/Relu;model/conv1d_5/BiasAdd;model/conv1d_5/Conv1D/Squeeze;model/conv1d_5/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_5/Conv1D__142:0']
# ---
# Node name: model/conv1d_5/Relu;model/conv1d_5/BiasAdd;model/conv1d_5/Conv1D/Squeeze;model/conv1d_5/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_5/Relu;model/conv1d_5/BiasAdd;model/conv1d_5/Conv1D/Squeeze;model/conv1d_5/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_5/Conv1D__142:0', 'const_fold_opt__439']
# Outputs: ['model/conv1d_5/Relu;model/conv1d_5/BiasAdd;model/conv1d_5/Conv1D/Squeeze;model/conv1d_5/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_5/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_5/Relu;model/conv1d_5/BiasAdd;model/conv1d_5/Conv1D/Squeeze;model/conv1d_5/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_5/Max']
# ---
# Node name: Relu__8
# Node type: Relu
# Inputs: ['model/conv1d_11/Relu;model/conv1d_11/BiasAdd;model/conv1d_11/Conv1D/Squeeze;model/conv1d_11/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_11/Conv1D']
# Outputs: ['Relu__8:0']
# ---
# Node name: model/conv1d_11/Relu;model/conv1d_11/BiasAdd;model/conv1d_11/Conv1D/Squeeze;model/conv1d_11/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_11/Conv1D__277
# Node type: Transpose
# Inputs: ['Relu__8:0']
# Outputs: ['model/conv1d_11/Relu;model/conv1d_11/BiasAdd;model/conv1d_11/Conv1D/Squeeze;model/conv1d_11/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_11/Conv1D__277:0']
# ---
# Node name: model/conv1d_11/Relu;model/conv1d_11/BiasAdd;model/conv1d_11/Conv1D/Squeeze;model/conv1d_11/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_11/Relu;model/conv1d_11/BiasAdd;model/conv1d_11/Conv1D/Squeeze;model/conv1d_11/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_11/Conv1D__277:0', 'const_fold_opt__357']
# Outputs: ['model/conv1d_11/Relu;model/conv1d_11/BiasAdd;model/conv1d_11/Conv1D/Squeeze;model/conv1d_11/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_11/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_11/Relu;model/conv1d_11/BiasAdd;model/conv1d_11/Conv1D/Squeeze;model/conv1d_11/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_11/Max']
# ---
# Node name: Relu__77
# Node type: Relu
# Inputs: ['model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D']
# Outputs: ['Relu__77:0']
# ---
# Node name: model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D__150
# Node type: Transpose
# Inputs: ['Relu__77:0']
# Outputs: ['model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D__150:0']
# ---
# Node name: model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_34/Conv1D__150:0', 'const_fold_opt__410']
# Outputs: ['model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_34/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_34/Relu;model/conv1d_34/BiasAdd;model/conv1d_34/Conv1D/Squeeze;model/conv1d_34/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_34/Max']
# ---
# Node name: Relu__74
# Node type: Relu
# Inputs: ['model/conv1d_33/Relu;model/conv1d_33/BiasAdd;model/conv1d_33/Conv1D/Squeeze;model/conv1d_33/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_33/Conv1D']
# Outputs: ['Relu__74:0']
# ---
# Node name: model/conv1d_33/Relu;model/conv1d_33/BiasAdd;model/conv1d_33/Conv1D/Squeeze;model/conv1d_33/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_33/Conv1D__155
# Node type: Transpose
# Inputs: ['Relu__74:0']
# Outputs: ['model/conv1d_33/Relu;model/conv1d_33/BiasAdd;model/conv1d_33/Conv1D/Squeeze;model/conv1d_33/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_33/Conv1D__155:0']
# ---
# Node name: model/conv1d_33/Relu;model/conv1d_33/BiasAdd;model/conv1d_33/Conv1D/Squeeze;model/conv1d_33/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_33/Relu;model/conv1d_33/BiasAdd;model/conv1d_33/Conv1D/Squeeze;model/conv1d_33/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_33/Conv1D__155:0', 'const_fold_opt__410']
# Outputs: ['model/conv1d_33/Relu;model/conv1d_33/BiasAdd;model/conv1d_33/Conv1D/Squeeze;model/conv1d_33/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_33/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_33/Relu;model/conv1d_33/BiasAdd;model/conv1d_33/Conv1D/Squeeze;model/conv1d_33/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_33/Max']
# ---
# Node name: Relu__71
# Node type: Relu
# Inputs: ['model/conv1d_32/Relu;model/conv1d_32/BiasAdd;model/conv1d_32/Conv1D/Squeeze;model/conv1d_32/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_32/Conv1D']
# Outputs: ['Relu__71:0']
# ---
# Node name: model/conv1d_32/Relu;model/conv1d_32/BiasAdd;model/conv1d_32/Conv1D/Squeeze;model/conv1d_32/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_32/Conv1D__160
# Node type: Transpose
# Inputs: ['Relu__71:0']
# Outputs: ['model/conv1d_32/Relu;model/conv1d_32/BiasAdd;model/conv1d_32/Conv1D/Squeeze;model/conv1d_32/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_32/Conv1D__160:0']
# ---
# Node name: model/conv1d_32/Relu;model/conv1d_32/BiasAdd;model/conv1d_32/Conv1D/Squeeze;model/conv1d_32/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_32/Relu;model/conv1d_32/BiasAdd;model/conv1d_32/Conv1D/Squeeze;model/conv1d_32/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_32/Conv1D__160:0', 'const_fold_opt__410']
# Outputs: ['model/conv1d_32/Relu;model/conv1d_32/BiasAdd;model/conv1d_32/Conv1D/Squeeze;model/conv1d_32/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_32/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_32/Relu;model/conv1d_32/BiasAdd;model/conv1d_32/Conv1D/Squeeze;model/conv1d_32/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_32/Max']
# ---
# Node name: Relu__68
# Node type: Relu
# Inputs: ['model/conv1d_31/Relu;model/conv1d_31/BiasAdd;model/conv1d_31/Conv1D/Squeeze;model/conv1d_31/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_31/Conv1D']
# Outputs: ['Relu__68:0']
# ---
# Node name: model/conv1d_31/Relu;model/conv1d_31/BiasAdd;model/conv1d_31/Conv1D/Squeeze;model/conv1d_31/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_31/Conv1D__165
# Node type: Transpose
# Inputs: ['Relu__68:0']
# Outputs: ['model/conv1d_31/Relu;model/conv1d_31/BiasAdd;model/conv1d_31/Conv1D/Squeeze;model/conv1d_31/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_31/Conv1D__165:0']
# ---
# Node name: model/conv1d_31/Relu;model/conv1d_31/BiasAdd;model/conv1d_31/Conv1D/Squeeze;model/conv1d_31/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_31/Relu;model/conv1d_31/BiasAdd;model/conv1d_31/Conv1D/Squeeze;model/conv1d_31/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_31/Conv1D__165:0', 'const_fold_opt__410']
# Outputs: ['model/conv1d_31/Relu;model/conv1d_31/BiasAdd;model/conv1d_31/Conv1D/Squeeze;model/conv1d_31/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_31/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_31/Relu;model/conv1d_31/BiasAdd;model/conv1d_31/Conv1D/Squeeze;model/conv1d_31/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_31/Max']
# ---
# Node name: Relu__65
# Node type: Relu
# Inputs: ['model/conv1d_30/Relu;model/conv1d_30/BiasAdd;model/conv1d_30/Conv1D/Squeeze;model/conv1d_30/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_30/Conv1D']
# Outputs: ['Relu__65:0']
# ---
# Node name: model/conv1d_30/Relu;model/conv1d_30/BiasAdd;model/conv1d_30/Conv1D/Squeeze;model/conv1d_30/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_30/Conv1D__170
# Node type: Transpose
# Inputs: ['Relu__65:0']
# Outputs: ['model/conv1d_30/Relu;model/conv1d_30/BiasAdd;model/conv1d_30/Conv1D/Squeeze;model/conv1d_30/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_30/Conv1D__170:0']
# ---
# Node name: model/conv1d_30/Relu;model/conv1d_30/BiasAdd;model/conv1d_30/Conv1D/Squeeze;model/conv1d_30/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_30/Relu;model/conv1d_30/BiasAdd;model/conv1d_30/Conv1D/Squeeze;model/conv1d_30/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_30/Conv1D__170:0', 'const_fold_opt__410']
# Outputs: ['model/conv1d_30/Relu;model/conv1d_30/BiasAdd;model/conv1d_30/Conv1D/Squeeze;model/conv1d_30/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_30/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_30/Relu;model/conv1d_30/BiasAdd;model/conv1d_30/Conv1D/Squeeze;model/conv1d_30/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_30/Max']
# ---
# Node name: Relu__62
# Node type: Relu
# Inputs: ['model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D']
# Outputs: ['Relu__62:0']
# ---
# Node name: model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D__178
# Node type: Transpose
# Inputs: ['Relu__62:0']
# Outputs: ['model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D__178:0']
# ---
# Node name: model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_29/Conv1D__178:0', 'const_fold_opt__439']
# Outputs: ['model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_29/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_29/Relu;model/conv1d_29/BiasAdd;model/conv1d_29/Conv1D/Squeeze;model/conv1d_29/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_29/Max']
# ---
# Node name: Relu__59
# Node type: Relu
# Inputs: ['model/conv1d_28/Relu;model/conv1d_28/BiasAdd;model/conv1d_28/Conv1D/Squeeze;model/conv1d_28/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_28/Conv1D']
# Outputs: ['Relu__59:0']
# ---
# Node name: model/conv1d_28/Relu;model/conv1d_28/BiasAdd;model/conv1d_28/Conv1D/Squeeze;model/conv1d_28/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_28/Conv1D__183
# Node type: Transpose
# Inputs: ['Relu__59:0']
# Outputs: ['model/conv1d_28/Relu;model/conv1d_28/BiasAdd;model/conv1d_28/Conv1D/Squeeze;model/conv1d_28/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_28/Conv1D__183:0']
# ---
# Node name: model/conv1d_28/Relu;model/conv1d_28/BiasAdd;model/conv1d_28/Conv1D/Squeeze;model/conv1d_28/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_28/Relu;model/conv1d_28/BiasAdd;model/conv1d_28/Conv1D/Squeeze;model/conv1d_28/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_28/Conv1D__183:0', 'const_fold_opt__439']
# Outputs: ['model/conv1d_28/Relu;model/conv1d_28/BiasAdd;model/conv1d_28/Conv1D/Squeeze;model/conv1d_28/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_28/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_28/Relu;model/conv1d_28/BiasAdd;model/conv1d_28/Conv1D/Squeeze;model/conv1d_28/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_28/Max']
# ---
# Node name: Relu__56
# Node type: Relu
# Inputs: ['model/conv1d_27/Relu;model/conv1d_27/BiasAdd;model/conv1d_27/Conv1D/Squeeze;model/conv1d_27/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_27/Conv1D']
# Outputs: ['Relu__56:0']
# ---
# Node name: model/conv1d_27/Relu;model/conv1d_27/BiasAdd;model/conv1d_27/Conv1D/Squeeze;model/conv1d_27/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_27/Conv1D__188
# Node type: Transpose
# Inputs: ['Relu__56:0']
# Outputs: ['model/conv1d_27/Relu;model/conv1d_27/BiasAdd;model/conv1d_27/Conv1D/Squeeze;model/conv1d_27/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_27/Conv1D__188:0']
# ---
# Node name: model/conv1d_27/Relu;model/conv1d_27/BiasAdd;model/conv1d_27/Conv1D/Squeeze;model/conv1d_27/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_27/Relu;model/conv1d_27/BiasAdd;model/conv1d_27/Conv1D/Squeeze;model/conv1d_27/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_27/Conv1D__188:0', 'const_fold_opt__439']
# Outputs: ['model/conv1d_27/Relu;model/conv1d_27/BiasAdd;model/conv1d_27/Conv1D/Squeeze;model/conv1d_27/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_27/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_27/Relu;model/conv1d_27/BiasAdd;model/conv1d_27/Conv1D/Squeeze;model/conv1d_27/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_27/Max']
# ---
# Node name: Relu__53
# Node type: Relu
# Inputs: ['model/conv1d_26/Relu;model/conv1d_26/BiasAdd;model/conv1d_26/Conv1D/Squeeze;model/conv1d_26/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_26/Conv1D']
# Outputs: ['Relu__53:0']
# ---
# Node name: model/conv1d_26/Relu;model/conv1d_26/BiasAdd;model/conv1d_26/Conv1D/Squeeze;model/conv1d_26/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_26/Conv1D__193
# Node type: Transpose
# Inputs: ['Relu__53:0']
# Outputs: ['model/conv1d_26/Relu;model/conv1d_26/BiasAdd;model/conv1d_26/Conv1D/Squeeze;model/conv1d_26/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_26/Conv1D__193:0']
# ---
# Node name: model/conv1d_26/Relu;model/conv1d_26/BiasAdd;model/conv1d_26/Conv1D/Squeeze;model/conv1d_26/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_26/Relu;model/conv1d_26/BiasAdd;model/conv1d_26/Conv1D/Squeeze;model/conv1d_26/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_26/Conv1D__193:0', 'const_fold_opt__439']
# ...
# ---
# Node name: model/global_max_pooling1d_19/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_19/Relu;model/conv1d_19/BiasAdd;model/conv1d_19/Conv1D/Squeeze;model/conv1d_19/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_19/Max']
# ---
# Node name: Relu__29
# Node type: Relu
# Inputs: ['model/conv1d_18/Relu;model/conv1d_18/BiasAdd;model/conv1d_18/Conv1D/Squeeze;model/conv1d_18/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_18/Conv1D']
# Outputs: ['Relu__29:0']
# ---
# Node name: model/conv1d_18/Relu;model/conv1d_18/BiasAdd;model/conv1d_18/Conv1D/Squeeze;model/conv1d_18/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_18/Conv1D__239
# Node type: Transpose
# Inputs: ['Relu__29:0']
# Outputs: ['model/conv1d_18/Relu;model/conv1d_18/BiasAdd;model/conv1d_18/Conv1D/Squeeze;model/conv1d_18/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_18/Conv1D__239:0']
# ---
# Node name: model/conv1d_18/Relu;model/conv1d_18/BiasAdd;model/conv1d_18/Conv1D/Squeeze;model/conv1d_18/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_18/Relu;model/conv1d_18/BiasAdd;model/conv1d_18/Conv1D/Squeeze;model/conv1d_18/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_18/Conv1D__239:0', 'const_fold_opt__416']
# Outputs: ['model/conv1d_18/Relu;model/conv1d_18/BiasAdd;model/conv1d_18/Conv1D/Squeeze;model/conv1d_18/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_18/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_18/Relu;model/conv1d_18/BiasAdd;model/conv1d_18/Conv1D/Squeeze;model/conv1d_18/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_18/Max']
# ---
# Node name: Relu__26
# Node type: Relu
# Inputs: ['model/conv1d_17/Relu;model/conv1d_17/BiasAdd;model/conv1d_17/Conv1D/Squeeze;model/conv1d_17/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_17/Conv1D']
# Outputs: ['Relu__26:0']
# ---
# Node name: model/conv1d_17/Relu;model/conv1d_17/BiasAdd;model/conv1d_17/Conv1D/Squeeze;model/conv1d_17/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_17/Conv1D__244
# Node type: Transpose
# Inputs: ['Relu__26:0']
# Outputs: ['model/conv1d_17/Relu;model/conv1d_17/BiasAdd;model/conv1d_17/Conv1D/Squeeze;model/conv1d_17/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_17/Conv1D__244:0']
# ---
# Node name: model/conv1d_17/Relu;model/conv1d_17/BiasAdd;model/conv1d_17/Conv1D/Squeeze;model/conv1d_17/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_17/Relu;model/conv1d_17/BiasAdd;model/conv1d_17/Conv1D/Squeeze;model/conv1d_17/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_17/Conv1D__244:0', 'const_fold_opt__416']
# Outputs: ['model/conv1d_17/Relu;model/conv1d_17/BiasAdd;model/conv1d_17/Conv1D/Squeeze;model/conv1d_17/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_17/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_17/Relu;model/conv1d_17/BiasAdd;model/conv1d_17/Conv1D/Squeeze;model/conv1d_17/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_17/Max']
# ---
# Node name: Relu__23
# Node type: Relu
# Inputs: ['model/conv1d_16/Relu;model/conv1d_16/BiasAdd;model/conv1d_16/Conv1D/Squeeze;model/conv1d_16/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_16/Conv1D']
# Outputs: ['Relu__23:0']
# ---
# Node name: model/conv1d_16/Relu;model/conv1d_16/BiasAdd;model/conv1d_16/Conv1D/Squeeze;model/conv1d_16/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_16/Conv1D__249
# Node type: Transpose
# Inputs: ['Relu__23:0']
# Outputs: ['model/conv1d_16/Relu;model/conv1d_16/BiasAdd;model/conv1d_16/Conv1D/Squeeze;model/conv1d_16/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_16/Conv1D__249:0']
# ---
# Node name: model/conv1d_16/Relu;model/conv1d_16/BiasAdd;model/conv1d_16/Conv1D/Squeeze;model/conv1d_16/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_16/Relu;model/conv1d_16/BiasAdd;model/conv1d_16/Conv1D/Squeeze;model/conv1d_16/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_16/Conv1D__249:0', 'const_fold_opt__416']
# Outputs: ['model/conv1d_16/Relu;model/conv1d_16/BiasAdd;model/conv1d_16/Conv1D/Squeeze;model/conv1d_16/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_16/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_16/Relu;model/conv1d_16/BiasAdd;model/conv1d_16/Conv1D/Squeeze;model/conv1d_16/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_16/Max']
# ---
# Node name: Relu__20
# Node type: Relu
# Inputs: ['model/conv1d_15/Relu;model/conv1d_15/BiasAdd;model/conv1d_15/Conv1D/Squeeze;model/conv1d_15/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_15/Conv1D']
# Outputs: ['Relu__20:0']
# ---
# Node name: model/conv1d_15/Relu;model/conv1d_15/BiasAdd;model/conv1d_15/Conv1D/Squeeze;model/conv1d_15/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_15/Conv1D__254
# Node type: Transpose
# Inputs: ['Relu__20:0']
# Outputs: ['model/conv1d_15/Relu;model/conv1d_15/BiasAdd;model/conv1d_15/Conv1D/Squeeze;model/conv1d_15/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_15/Conv1D__254:0']
# ---
# Node name: model/conv1d_15/Relu;model/conv1d_15/BiasAdd;model/conv1d_15/Conv1D/Squeeze;model/conv1d_15/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_15/Relu;model/conv1d_15/BiasAdd;model/conv1d_15/Conv1D/Squeeze;model/conv1d_15/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_15/Conv1D__254:0', 'const_fold_opt__416']
# Outputs: ['model/conv1d_15/Relu;model/conv1d_15/BiasAdd;model/conv1d_15/Conv1D/Squeeze;model/conv1d_15/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_15/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_15/Relu;model/conv1d_15/BiasAdd;model/conv1d_15/Conv1D/Squeeze;model/conv1d_15/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_15/Max']
# ---
# Node name: Relu__17
# Node type: Relu
# Inputs: ['model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D']
# Outputs: ['Relu__17:0']
# ---
# Node name: model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D__262
# Node type: Transpose
# Inputs: ['Relu__17:0']
# Outputs: ['model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D__262:0']
# ---
# Node name: model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_14/Conv1D__262:0', 'const_fold_opt__357']
# Outputs: ['model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_14/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_14/Relu;model/conv1d_14/BiasAdd;model/conv1d_14/Conv1D/Squeeze;model/conv1d_14/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_14/Max']
# ---
# Node name: Relu__14
# Node type: Relu
# Inputs: ['model/conv1d_13/Relu;model/conv1d_13/BiasAdd;model/conv1d_13/Conv1D/Squeeze;model/conv1d_13/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_13/Conv1D']
# Outputs: ['Relu__14:0']
# ---
# Node name: model/conv1d_13/Relu;model/conv1d_13/BiasAdd;model/conv1d_13/Conv1D/Squeeze;model/conv1d_13/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_13/Conv1D__267
# Node type: Transpose
# Inputs: ['Relu__14:0']
# Outputs: ['model/conv1d_13/Relu;model/conv1d_13/BiasAdd;model/conv1d_13/Conv1D/Squeeze;model/conv1d_13/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_13/Conv1D__267:0']
# ---
# Node name: model/conv1d_13/Relu;model/conv1d_13/BiasAdd;model/conv1d_13/Conv1D/Squeeze;model/conv1d_13/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_13/Relu;model/conv1d_13/BiasAdd;model/conv1d_13/Conv1D/Squeeze;model/conv1d_13/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_13/Conv1D__267:0', 'const_fold_opt__357']
# Outputs: ['model/conv1d_13/Relu;model/conv1d_13/BiasAdd;model/conv1d_13/Conv1D/Squeeze;model/conv1d_13/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_13/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_13/Relu;model/conv1d_13/BiasAdd;model/conv1d_13/Conv1D/Squeeze;model/conv1d_13/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_13/Max']
# ---
# Node name: Relu__11
# Node type: Relu
# Inputs: ['model/conv1d_12/Relu;model/conv1d_12/BiasAdd;model/conv1d_12/Conv1D/Squeeze;model/conv1d_12/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_12/Conv1D']
# Outputs: ['Relu__11:0']
# ---
# Node name: model/conv1d_12/Relu;model/conv1d_12/BiasAdd;model/conv1d_12/Conv1D/Squeeze;model/conv1d_12/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_12/Conv1D__272
# Node type: Transpose
# Inputs: ['Relu__11:0']
# Outputs: ['model/conv1d_12/Relu;model/conv1d_12/BiasAdd;model/conv1d_12/Conv1D/Squeeze;model/conv1d_12/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_12/Conv1D__272:0']
# ---
# Node name: model/conv1d_12/Relu;model/conv1d_12/BiasAdd;model/conv1d_12/Conv1D/Squeeze;model/conv1d_12/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_12/Relu;model/conv1d_12/BiasAdd;model/conv1d_12/Conv1D/Squeeze;model/conv1d_12/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_12/Conv1D__272:0', 'const_fold_opt__357']
# Outputs: ['model/conv1d_12/Relu;model/conv1d_12/BiasAdd;model/conv1d_12/Conv1D/Squeeze;model/conv1d_12/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_12/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_12/Relu;model/conv1d_12/BiasAdd;model/conv1d_12/Conv1D/Squeeze;model/conv1d_12/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_12/Max']
# ---
# Node name: Relu__107
# Node type: Relu
# Inputs: ['model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D']
# Outputs: ['Relu__107:0']
# ---
# Node name: model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D__290
# Node type: Transpose
# Inputs: ['Relu__107:0']
# Outputs: ['model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D__290:0']
# ---
# Node name: model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D__290:0', 'const_fold_opt__435']
# Outputs: ['model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_4/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_4/Relu;model/conv1d_4/BiasAdd;model/conv1d_4/Conv1D/Squeeze;model/conv1d_4/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_4/Max']
# ---
# Node name: Relu__104
# Node type: Relu
# Inputs: ['model/conv1d_3/Relu;model/conv1d_3/BiasAdd;model/conv1d_3/Conv1D/Squeeze;model/conv1d_3/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_3/Conv1D']
# Outputs: ['Relu__104:0']
# ---
# Node name: model/conv1d_3/Relu;model/conv1d_3/BiasAdd;model/conv1d_3/Conv1D/Squeeze;model/conv1d_3/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_3/Conv1D__295
# Node type: Transpose
# Inputs: ['Relu__104:0']
# Outputs: ['model/conv1d_3/Relu;model/conv1d_3/BiasAdd;model/conv1d_3/Conv1D/Squeeze;model/conv1d_3/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_3/Conv1D__295:0']
# ---
# Node name: model/conv1d_3/Relu;model/conv1d_3/BiasAdd;model/conv1d_3/Conv1D/Squeeze;model/conv1d_3/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_3/Relu;model/conv1d_3/BiasAdd;model/conv1d_3/Conv1D/Squeeze;model/conv1d_3/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_3/Conv1D__295:0', 'const_fold_opt__435']
# Outputs: ['model/conv1d_3/Relu;model/conv1d_3/BiasAdd;model/conv1d_3/Conv1D/Squeeze;model/conv1d_3/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_3/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_3/Relu;model/conv1d_3/BiasAdd;model/conv1d_3/Conv1D/Squeeze;model/conv1d_3/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_3/Max']
# ---
# Node name: Relu__101
# Node type: Relu
# Inputs: ['model/conv1d_2/Relu;model/conv1d_2/BiasAdd;model/conv1d_2/Conv1D/Squeeze;model/conv1d_2/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_2/Conv1D']
# Outputs: ['Relu__101:0']
# ---
# Node name: model/conv1d_2/Relu;model/conv1d_2/BiasAdd;model/conv1d_2/Conv1D/Squeeze;model/conv1d_2/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_2/Conv1D__300
# Node type: Transpose
# Inputs: ['Relu__101:0']
# Outputs: ['model/conv1d_2/Relu;model/conv1d_2/BiasAdd;model/conv1d_2/Conv1D/Squeeze;model/conv1d_2/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_2/Conv1D__300:0']
# ---
# Node name: model/conv1d_2/Relu;model/conv1d_2/BiasAdd;model/conv1d_2/Conv1D/Squeeze;model/conv1d_2/BiasAdd/ReadVariableOp
# Node type: Reshape
# Inputs: ['model/conv1d_2/Relu;model/conv1d_2/BiasAdd;model/conv1d_2/Conv1D/Squeeze;model/conv1d_2/BiasAdd/ReadVariableOp;model/conv1d_4/Conv1D;model/conv1d_2/Conv1D__300:0', 'const_fold_opt__435']
# Outputs: ['model/conv1d_2/Relu;model/conv1d_2/BiasAdd;model/conv1d_2/Conv1D/Squeeze;model/conv1d_2/BiasAdd/ReadVariableOp']
# ---
# Node name: model/global_max_pooling1d_2/Max
# Node type: ReduceMax
# Inputs: ['model/conv1d_2/Relu;model/conv1d_2/BiasAdd;model/conv1d_2/Conv1D/Squeeze;model/conv1d_2/BiasAdd/ReadVariableOp']
# Outputs: ['model/global_max_pooling1d_2/Max']
# ---
# Node name: model/concatenate/concat
# Node type: Concat
# Inputs: ['model/global_max_pooling1d/Max', 'model/global_max_pooling1d_1/Max', 'model/global_max_pooling1d_2/Max', 'model/global_max_pooling1d_3/Max', 'model/global_max_pooling1d_4/Max', 'model/global_max_pooling1d_5/Max', 'model/global_max_pooling1d_6/Max', 'model/global_max_pooling1d_7/Max', 'model/global_max_pooling1d_8/Max', 'model/global_max_pooling1d_9/Max', 'model/global_max_pooling1d_10/Max', 'model/global_max_pooling1d_11/Max', 'model/global_max_pooling1d_12/Max', 'model/global_max_pooling1d_13/Max', 'model/global_max_pooling1d_14/Max', 'model/global_max_pooling1d_15/Max', 'model/global_max_pooling1d_16/Max', 'model/global_max_pooling1d_17/Max', 'model/global_max_pooling1d_18/Max', 'model/global_max_pooling1d_19/Max', 'model/global_max_pooling1d_20/Max', 'model/global_max_pooling1d_21/Max', 'model/global_max_pooling1d_22/Max', 'model/global_max_pooling1d_23/Max', 'model/global_max_pooling1d_24/Max', 'model/global_max_pooling1d_25/Max', 'model/global_max_pooling1d_26/Max', 'model/global_max_pooling1d_27/Max', 'model/global_max_pooling1d_28/Max', 'model/global_max_pooling1d_29/Max', 'model/global_max_pooling1d_30/Max', 'model/global_max_pooling1d_31/Max', 'model/global_max_pooling1d_32/Max', 'model/global_max_pooling1d_33/Max', 'model/global_max_pooling1d_34/Max']
# Outputs: ['model/concatenate/concat']
# ---
# Node name: model/dense/MatMul;model/dense/BiasAdd
# Node type: MatMul
# Inputs: ['model/concatenate/concat', 'const_fold_opt__376']
# Outputs: ['model/dense/MatMul;model/dense/BiasAdd']
# ---
# Node name: Add__111
# Node type: Add
# Inputs: ['model/dense/MatMul;model/dense/BiasAdd', 'model/dense/BiasAdd/ReadVariableOp']
# Outputs: ['Add__111:0']
# ---
# Node name: model/dense/Sigmoid
# Node type: Sigmoid
# Inputs: ['Add__111:0']
# Outputs: ['model/dense/Sigmoid']
# ---
# Node name: model/dense_1/MatMul;model/dense_1/BiasAdd
# Node type: MatMul
# Inputs: ['model/dense/Sigmoid', 'const_fold_opt__399']
# Outputs: ['model/dense_1/MatMul;model/dense_1/BiasAdd']
# ---
# Node name: Add__114
# Node type: Add
# Inputs: ['model/dense_1/MatMul;model/dense_1/BiasAdd', 'model/dense_1/BiasAdd/ReadVariableOp']
# Outputs: ['Add__114:0']
# ---
# Node name: StatefulPartitionedCall:0
# Node type: Sigmoid
# Inputs: ['Add__114:0']
# Outputs: ['StatefulPartitionedCall:0']
# ---

# %%
def load_model(path):
    # Create an inference session with onnxruntime
    return ort.InferenceSession(path)

def compute_metrics(y_true, y_pred):
    accuracy = (np.array(y_pred) == np.array(y_true)).mean()
    auc = roc_auc_score(y_true, y_pred)
    return accuracy, auc

def eval(test_data, outdir, model_name, model_type, seed=15, batch_size=64):
    # Set random seed
    np.random.seed(seed)  # Numpy module.
    random.seed(seed)  # Python random module.
    # Read in data
    test_df = pd.read_csv(test_data)
    test_data = CustomDataset(test_data, ENCODING)
    data_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True)
    pep_list = list(test_df.peptide.value_counts(ascending=False).index)

# %%
session = load_model("models/onnx/t.0.v.1.onnx")
input_name = session.get_inputs()[0].name  # Get the input name for the model

# %%
ENCODING = blosum50_20aa

# %%
test_data_path = "/Users/chenweijia/Documents/code/nettcr_pytorch/data/train_example.csv"
test_data = CustomDataset(test_data_path, ENCODING, isEval=True)
data_loader = DataLoader(test_data, batch_size=64, shuffle=True)

# %%
y_pred = []
y_true = []

# %%
input_data = {k:v.cpu().numpy() for k,v in data.items()}

# %%
for batch_idx, (data, labels, weight) in enumerate(data_loader):
    # Convert data to a format suitable for ONNX runtime (numpy)
    # data = [i.to(device) for i in data]
    # labels = labels.to(device)
    # Run inference
    outputs = session.run(None, input_data)

    # Convert outputs to tensor and get predictions
    outputs_tensor = torch.tensor(outputs[0])
    preds = (outputs_tensor > 0.5).to(torch.float32)

    preds.squeeze()

    # Store predictions and true labels
    y_pred.extend(preds.numpy())
    y_true.extend(labels.numpy())

    print(f"Batch id: {batch_idx}/{len(data_loader)}")
    accuracy, auc = compute_metrics(y_true, y_pred)
    print(f"Accuracy: {accuracy}, AUC: {auc}")
# Out:
# Batch id: 0/324
# Accuracy: 0.7377431441326531, AUC: 0.5347397260273972
# Batch id: 1/324
# Accuracy: 0.7295074462890625, AUC: 0.5120892494929007
# Batch id: 2/324
# Accuracy: 0.7279730902777778, AUC: 0.511428448442847
# Batch id: 3/324
# Accuracy: 0.724599609375, AUC: 0.5311166398866601
# Batch id: 4/324
# Accuracy: 0.7237780862603306, AUC: 0.5289736407383465
# Batch id: 5/324
# Accuracy: 0.7195841471354166, AUC: 0.5280978035640282
# Batch id: 6/324
# Accuracy: 0.7192758413461539, AUC: 0.5222984562607204
# Batch id: 7/324
# Accuracy: 0.7197464923469388, AUC: 0.5220005659309565
# Batch id: 8/324
# Accuracy: 0.7153125, AUC: 0.5348124098124099
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 for batch_idx, (data, labels, weight) in enumerate(data_loader):
#       2     # Convert data to a format suitable for ONNX runtime (numpy)
#       3     # data = [i.to(device) for i in data]
#       4     # labels = labels.to(device)
#       5     # Run inference
#       6     outputs = session.run(None, input_data)
#       8     # Convert outputs to tensor and get predictions
#
# File ~/anaconda3/envs/nettcr_2_2_env/lib/python3.10/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/nettcr_2_2_env/lib/python3.10/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/nettcr_2_2_env/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/nettcr_2_2_env/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/Documents/code/nettcr_pytorch/src/dataset.py:35, in CustomDataset.__getitem__(self, idx)
#      33     return [xx[idx,:,:] for xx in X], y[idx], weights[idx]
#      34 else:
# ---> 35     X, y, weights = make_sequence_ds_eval(self.df, encoding = self.encoding) # X_train, targets_train, weights_train
#      36     return {k: v[idx] for k, v in X.items()}, y[idx], weights[idx]
#
# File ~/Documents/code/nettcr_pytorch/src/utils.py:179, in make_sequence_ds_eval(df, encoding)
#     173 """Encodes amino acid sequences using a BLOSUM50 matrix with a normalization factor of 5.
#     174 Sequences are right-padded with [-1x20] for each AA missing, compared to the maximum embedding
#     175 length for that given feature
#     176
#     177 Additionally, the input is prepared for predictions, by loading the data into a list of numpy arrays"""
#     178 encoded_pep = enc_list_bl_max_len(df.peptide, encoding, pep_max)/5
# --> 179 encoded_a1 = enc_list_bl_max_len(df.A1, encoding, a1_max)/5
#     180 encoded_a2 = enc_list_bl_max_len(df.A2, encoding, a2_max)/5
#     181 encoded_a3 = enc_list_bl_max_len(df.A3, encoding, a3_max)/5
#
# File ~/Documents/code/nettcr_pytorch/src/utils.py:61, in enc_list_bl_max_len(aa_seqs, blosum, max_seq_len, padding, pad_value)
#      59 if aa in blosum:
#      60     e_seq[count]=blosum[aa]
# ---> 61     count+=1
#      62 else:
#      63     sys.stderr.write("Unknown amino acid in peptides: "+ aa +", encoding aborted!\n")
#
# KeyboardInterrupt:
